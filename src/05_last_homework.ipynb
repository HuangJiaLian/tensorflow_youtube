# %%
# Solution: 
# Change lr dynamically
# keep_prob >= 0.9

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

LAYER1_NODE = 500
LAYER2_NODE = 500
LAYER3_NODE = 500
LAYER4_NODE = 500

# Load data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)

batch_size = 200
# Number of batch 
n_batch = mnist.train.num_examples // batch_size

# Define placeholder
x = tf.placeholder(tf.float32,[None, 784])
y = tf.placeholder(tf.float32,[None, 10]) # Lable
keep_prob = tf.placeholder(tf.float32) # How much percentage of node is working
# ** Solution **
lr = tf.Variable(0.001, dtype=tf.float32)

# Build Network
W1 = tf.Variable(tf.truncated_normal([784,LAYER1_NODE],stddev=0.1))
b1 = tf.Variable(tf.zeros([LAYER1_NODE]) + 0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1) + b1)
L1_drop = tf.nn.dropout(L1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([LAYER1_NODE,LAYER2_NODE],stddev=0.1))
b2 = tf.Variable(tf.zeros([LAYER2_NODE]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2) + b2)
L2_drop = tf.nn.dropout(L2, keep_prob)

W3 = tf.Variable(tf.truncated_normal([LAYER2_NODE,LAYER3_NODE],stddev=0.1))
b3 = tf.Variable(tf.zeros([LAYER3_NODE]) + 0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3) + b3)
L3_drop = tf.nn.dropout(L3, keep_prob)


W4 = tf.Variable(tf.truncated_normal([LAYER3_NODE,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10]) + 0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)


# quadratic cost
# loss = tf.reduce_mean(tf.square(y-prediction))
# cross entropy loss function 
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))

# train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
# ** Solution **
train_step = tf.train.AdamOptimizer(lr).minimize(loss)

init = tf.global_variables_initializer()


# correct_prediction：A boolean list
# argmax: return the index of max value 
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction,1))
# Get accuracy rate: 
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(61):
        # ** Solution **
        sess.run(tf.assign(lr, 0.001*(0.95**epoch)))
        for batch in range(n_batch):
            # Store image in batch_xs, lable in batch_ys
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys, keep_prob:0.9})
        test_acc = sess.run(accuracy, feed_dict={x:mnist.test.images,y:mnist.test.labels, keep_prob:1.0})
        train_acc = sess.run(accuracy, feed_dict={x:mnist.train.images,y:mnist.train.labels, keep_prob:1.0})
        print("Iter " + str(epoch) + ", Testing Accuracy " + str(test_acc),", Training Accuracy " + str(train_acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0, Testing Accuracy 0.9495 , Training Accuracy 0.9514727
# Iter 1, Testing Accuracy 0.9591 , Training Accuracy 0.96363634
# Iter 2, Testing Accuracy 0.9651 , Training Accuracy 0.9718909
# Iter 3, Testing Accuracy 0.9681 , Training Accuracy 0.97778183
# Iter 4, Testing Accuracy 0.9727 , Training Accuracy 0.98194546
# Iter 5, Testing Accuracy 0.973 , Training Accuracy 0.98465455
# Iter 6, Testing Accuracy 0.9748 , Training Accuracy 0.9859273
# Iter 7, Testing Accuracy 0.9732 , Training Accuracy 0.98716366
# Iter 8, Testing Accuracy 0.975 , Training Accuracy 0.9886
# Iter 9, Testing Accuracy 0.9746 , Training Accuracy 0.9891273
# Iter 10, Testing Accuracy 0.9769 , Training Accuracy 0.99087274
# Iter 11, Testing Accuracy 0.9761 , Training Accuracy 0.99087274
# Iter 12, Testing Accuracy 0.9766 , Training Accuracy 0.99176365
# Iter 13, Testing Accuracy 0.9777 , Training Accuracy 0.99225456
# Iter 14, Testing Accuracy 0.9801 , Training Accuracy 0.9938
# Iter 15, Testing Accuracy 0.9787 , Training Accuracy 0.99416363
# Iter 16, Testing Accuracy 0.978 , Training Accuracy 0.9944909
# Iter 17, Testing Accuracy 0.9794 , Training Accuracy 0.99487275
# Iter 18, Testing Accuracy 0.9802 , Training Accuracy 0.9953273
# Iter 19, Testing Accuracy 0.9813 , Training Accuracy 0.9954
# Iter 20, Testing Accuracy 0.9801 , Training Accuracy 0.99563634
# Iter 21, Testing Accuracy 0.9801 , Training Accuracy 0.9956909
# Iter 22, Testing Accuracy 0.9807 , Training Accuracy 0.9959273
# Iter 23, Testing Accuracy 0.9813 , Training Accuracy 0.99596363
# Iter 24, Testing Accuracy 0.9808 , Training Accuracy 0.99618185
# Iter 25, Testing Accuracy 0.9786 , Training Accuracy 0.9962
# Iter 26, Testing Accuracy 0.9808 , Training Accuracy 0.99625456
# Iter 27, Testing Accuracy 0.9796 , Training Accuracy 0.99634546
# Iter 28, Testing Accuracy 0.9814 , Training Accuracy 0.99636364
# Iter 29, Testing Accuracy 0.9798 , Training Accuracy 0.99645454
# Iter 30, Testing Accuracy 0.9803 , Training Accuracy 0.99674547
# Iter 31, Testing Accuracy 0.9813 , Training Accuracy 0.99674547
# Iter 32, Testing Accuracy 0.98 , Training Accuracy 0.9967818
# Iter 33, Testing Accuracy 0.9814 , Training Accuracy 0.9968182
# Iter 34, Testing Accuracy 0.9815 , Training Accuracy 0.9969091
# Iter 35, Testing Accuracy 0.9827 , Training Accuracy 0.9969818
# Iter 36, Testing Accuracy 0.9822 , Training Accuracy 0.99701816
# Iter 37, Testing Accuracy 0.9806 , Training Accuracy 0.9970545
# Iter 38, Testing Accuracy 0.9817 , Training Accuracy 0.99709094
# Iter 39, Testing Accuracy 0.9817 , Training Accuracy 0.9971455
# Iter 40, Testing Accuracy 0.9808 , Training Accuracy 0.9972182
# Iter 41, Testing Accuracy 0.982 , Training Accuracy 0.9972182
# Iter 42, Testing Accuracy 0.9813 , Training Accuracy 0.9972909
# Iter 43, Testing Accuracy 0.9816 , Training Accuracy 0.9973091
# Iter 44, Testing Accuracy 0.9824 , Training Accuracy 0.99734545
# Iter 45, Testing Accuracy 0.9826 , Training Accuracy 0.99734545
# Iter 46, Testing Accuracy 0.982 , Training Accuracy 0.9973636
# Iter 47, Testing Accuracy 0.9813 , Training Accuracy 0.9973818
# Iter 48, Testing Accuracy 0.982 , Training Accuracy 0.9973818
# Iter 49, Testing Accuracy 0.9823 , Training Accuracy 0.9974
# Iter 50, Testing Accuracy 0.9826 , Training Accuracy 0.99743634
# Iter 51, Testing Accuracy 0.9815 , Training Accuracy 0.9974727
# Iter 52, Testing Accuracy 0.9811 , Training Accuracy 0.99750906
# Iter 53, Testing Accuracy 0.9816 , Training Accuracy 0.9974909
# Iter 54, Testing Accuracy 0.9815 , Training Accuracy 0.9975273
# Iter 55, Testing Accuracy 0.9824 , Training Accuracy 0.9975273
# Iter 56, Testing Accuracy 0.9819 , Training Accuracy 0.9975273
# Iter 57, Testing Accuracy 0.9824 , Training Accuracy 0.99756366
# Iter 58, Testing Accuracy 0.9821 , Training Accuracy 0.99758184
# Iter 59, Testing Accuracy 0.982 , Training Accuracy 0.99758184
# Iter 60, Testing Accuracy 0.982 , Training Accuracy 0.99758184
